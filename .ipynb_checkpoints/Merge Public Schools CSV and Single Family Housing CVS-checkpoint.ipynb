# %%
# Dependencies
import pandas as pd

# %%
# The path to our CSV file
public_schools = "data/Public_Schools.csv"
single_family_housing = "data/Zip_Zhvi_SingleFamilyResidence.csv"

# Read our public school data into pandas
ps_df = pd.read_csv(public_schools)
ps_df.head()

#read out single family housing data into pandas
fl_sfh_df = pd.read_csv(single_family_housing)
fl_sfh_df.head()
# Out:
#    RegionID  RegionName      City State                             Metro  \
# 0     61639       10025  New York    NY       New York-Newark-Jersey City
# 1     84654       60657   Chicago    IL          Chicago-Naperville-Elgin
# 2     61637       10023  New York    NY       New York-Newark-Jersey City
# 3     91982       77494      Katy    TX  Houston-The Woodlands-Sugar Land
# 4     84616       60614   Chicago    IL          Chicago-Naperville-Elgin
#
#         CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2019-05  \
# 0  New York County         1       NaN       NaN       NaN  ...  1365272
# 1      Cook County         2  359973.0  358681.0  358365.0  ...   967517
# 2  New York County         3       NaN       NaN       NaN  ...  1506127
# 3    Harris County         4  198909.0  197774.0  197109.0  ...   335155
# 4      Cook County         5  542574.0  540261.0  540278.0  ...  1201189
#
#    2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  2019-12  2020-01  \
# ...

# %%
#Pull out the Florida Public Schools
fl_ps_df = ps_df.loc[ps_df["STATE"] == "FL"]

print(len(fl_ps_df))
fl_ps_df.head()
# Out:
# 4426
#              X          Y  OBJECTID        NCESID  \
# 26  -80.395561  27.299188      7131  1.201770e+11
# 29  -81.888046  26.555410      7134  1.201080e+11
# 53  -81.422091  28.383831      7158  1.201440e+11
# 101 -80.349017  25.935564      7207  1.200390e+11
# 141 -80.244758  26.707160      7247  1.201500e+11
#
#                                             NAME                   ADDRESS  \
# 26                           MANATEE ACADEMY K-8  1450 SW HEATHERWOOD BLVD
# 29   FLORIDA SOUTHWESTERN COLLEGIATE HIGH SCHOOL         8099 COLLEGE PKWY
# 53                         JOHN YOUNG ELEMENTARY       12550 MARSFIELD AVE
# 101            MATER ACADEMY LAKES MIDDLE SCHOOL         17300 NW 87TH AVE
# 141           ROYAL PALM BEACH ELEMENTARY SCHOOL     11911 OKEECHOBEE BLVD
#
#                  CITY STATE    ZIP  ZIP4  ...     VAL_METHOD  \
# 26      PORT ST LUCIE    FL  34986  2039  ...  IMAGERY/OTHER
# 29           FT MYERS    FL  33919  5566  ...  IMAGERY/OTHER
# ...

# %%
#reduce the number of columns
fl_ps_df = fl_ps_df.loc[:, ["NAME", "ADDRESS", "CITY",
                            "STATE", "ZIP", "WEBSITE", "LEVEL_", "ENROLLMENT", 
                            "ST_GRADE", "END_GRADE", "DISTRICTID", "FT_TEACHER", "SHELTER_ID"]]

fl_ps_df.head(10)
# Out:
#                                             NAME                   ADDRESS  \
# 26                           MANATEE ACADEMY K-8  1450 SW HEATHERWOOD BLVD
# 29   FLORIDA SOUTHWESTERN COLLEGIATE HIGH SCHOOL         8099 COLLEGE PKWY
# 53                         JOHN YOUNG ELEMENTARY       12550 MARSFIELD AVE
# 101            MATER ACADEMY LAKES MIDDLE SCHOOL         17300 NW 87TH AVE
# 141           ROYAL PALM BEACH ELEMENTARY SCHOOL     11911 OKEECHOBEE BLVD
# 152                            LOVELL ELEMENTARY     815 ROGER WILLIAMS RD
# 166             RAYMOND B. STEWART MIDDLE SCHOOL            38505 10TH AVE
# 170                  OLD KINGS ELEMENTARY SCHOOL        301 OLD KINGS RD S
# 179                     CARTER PARRAMORE ACADEMY          631 S STEWART ST
# 186                   KINGSWAY ELEMENTARY SCHOOL         23300 QUASAR BLVD
#
#                  CITY STATE    ZIP                                   WEBSITE  \
# ...

# %%
# Remove all rows that aren't located in Florida
fl_sfh_df = fl_sfh_df.loc[fl_sfh_df["State"] == "FL", :]
fl_sfh_df.head(2)
# Out:
#     RegionID  RegionName               City State  \
# 17     71831       32162       The Villages    FL
# 79     72463       33160  Sunny Isles Beach    FL
#
#                                     Metro         CountyName  SizeRank  \
# 17                           The Villages      Sumter County        18
# 79  Miami-Fort Lauderdale-West Palm Beach  Miami-Dade County        80
#
#      1996-04   1996-05   1996-06  ...  2019-05  2019-06  2019-07  2019-08  \
# 17  111507.0  111544.0  111474.0  ...   278141   279138   279977   281249
# 79  303421.0  302238.0  301635.0  ...   873916   873579   873098   873947
#
#     2019-09  2019-10  2019-11  2019-12  2020-01  2020-02
# 17   282423   283668   284454   285030   285625   286752
# 79   873773   873285   872098   871078   870056   873206
#
# [2 rows x 294 columns]

# %%
#reduce the number of columns
fl_sfh_df = fl_sfh_df.loc[:, ["RegionID", "RegionName", "City",
                            "State", "Metro", "CountyName", "SizeRank", "2019-01", 
                            "2019-02", "2019-03", "2019-04", "2019-05", "2019-06",
                             "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", 
                            "2019-12"]]

fl_sfh_df.rename(columns={'RegionName':'ZIP'}, inplace=True)


fl_sfh_df.head(20)
# Out:
#      RegionID    ZIP               City State  \
# 17      71831  32162       The Villages    FL
# 79      72463  33160  Sunny Isles Beach    FL
# 81      73221  34787      Winter Garden    FL
# 90      72578  33411   Royal Palm Beach    FL
# 96      72363  33025            Miramar    FL
# 101     72442  33139        Miami Beach    FL
# 133     71864  32210       Jacksonville    FL
# 147     72901  33908         Fort Myers    FL
# 157     72362  33024     Pembroke Pines    FL
# 167     72737  33647              Tampa    FL
# 191     73014  34135     Bonita Springs    FL
# 212     71871  32218       Jacksonville    FL
# 215     71902  32256       Jacksonville    FL
# 222     73183  34711           Clermont    FL
# 229     72347  33009         Hallandale    FL
# 245     71895  32244       Jacksonville    FL
# 260     72247  32822            Orlando    FL
# 264     73233  34953   Port Saint Lucie    FL
# 266     72488  33186      The Crossings    FL
# ...

# %%
fl_sfh_df['tmp'] = 1
fl_ps_df['tmp'] = 1

merged_df = pd.merge(fl_sfh_df, fl_ps_df, on=['tmp'])
merged_df = merged_df.drop('tmp', axis=1)

merged_df.head()
# Out:
#    RegionID  ZIP_x          City State         Metro     CountyName  SizeRank  \
# 0     71831  32162  The Villages    FL  The Villages  Sumter County        18
# 1     71831  32162  The Villages    FL  The Villages  Sumter County        18
# 2     71831  32162  The Villages    FL  The Villages  Sumter County        18
# 3     71831  32162  The Villages    FL  The Villages  Sumter County        18
# 4     71831  32162  The Villages    FL  The Villages  Sumter County        18
#
#    2019-01  2019-02  2019-03  ...  STATE  ZIP_y  \
# 0   274274   275668   276358  ...     FL  34986
# 1   274274   275668   276358  ...     FL  33919
# 2   274274   275668   276358  ...     FL  32837
# 3   274274   275668   276358  ...     FL  33015
# 4   274274   275668   276358  ...     FL  33411
#
#                                     WEBSITE  LEVEL_  ENROLLMENT  ST_GRADE  \
# 0         http://www.stlucie.k12.fl.us/MAN/       1        1374        KG
# ...
